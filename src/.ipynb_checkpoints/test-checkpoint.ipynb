# %% [markdown]
# # [CSI-30] Atividade 4  - Predictive analytics

# %% [markdown]
# ##### Importação de Bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pymssql
import csv
import time
import math
import warnings

from sklearn.linear_model import LinearRegression
from datetime import datetime, timedelta

# %%
warnings.filterwarnings('ignore')

# %%
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Conexão com o MSSQL Server 2017

# %%
conn = pymssql.connect(host='localhost', user='sa', password='Pent@gon1979', database='FI_DW')

# %%
conn.autocommit(True)

# %%
cursor = conn.cursor()

# %% [markdown]
# ##### Informações Diárias

# %%
path_files_date = [
                                                                                    202111, 202112,
    202201, 202202, 202203, 202204, 202205, 202206, 202207, 202208, 202209, 202210, 202211, 202212,
    202301, 202302, 202303, 202304, 202305, 202306, 202307, 202308, 202309, 202310  
]

# %%
inf_diario = pd.DataFrame()

# %%
for date in path_files_date:
    new_df = f"../data/inf_diario/inf_diario_fi_{date}.csv"
    inf_diario = pd.concat([inf_diario, pd.read_csv(new_df, sep=';')], axis=0)

# %% [markdown]
# ##### Informações cadastrais

# %%
cad = pd.read_csv('../data/cad/cad_fi.csv', sep=';', encoding='iso-8859-1', low_memory=False)

# %% [markdown]
# ## Data analytics

# %%
query1 = '''
    SELECT
        t.datetime AS DT_COMPTC,
        i.DenomSocial AS DENOM_SOCIAL,
        v.NetWorth AS 'VL_PATRIM_LIQ'
    FROM 
        fact_Value v
    JOIN 
        dim_Investment_Fund i ON v.id_dim_investment_fund = i.id_dim_investment_fund  
    JOIN 
        dim_Time t ON v.id_dim_time = t.id_dim_time
    WHERE
        i.TypeFund = 'FI' AND
        i.Situation = 'EM FUNCIONAMENTO NORMAL' AND
        i.NetWorth >= 100000000
'''


data = pd.read_sql(query1, conn)

# %%
data.sample(3)
# Out:
#         DT_COMPTC                                       DENOM_SOCIAL  \
# 16420  2021-11-04  FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO PRI...
# 72     2021-11-19  BB RENDA FIXA REFERENCIADO DI ÁGIL FUNDO DE IN...
# 11257  2021-11-30  BRADESCO FUNDO DE INVESTIMENTO EM COTAS DE FUN...
#
#        VL_PATRIM_LIQ
# 16420   1.825607e+10
# 72      5.780167e+09
# 11257   1.280303e+08

# %%
data = data.pivot_table(values='VL_PATRIM_LIQ', index='DT_COMPTC', columns='DENOM_SOCIAL')

# %%
data.head(3)
# Out:
# DENOM_SOCIAL  051 AÇÕES FUNDO DE INVESTIMENTO DE AÇÕES  \
# DT_COMPTC
# 2021-11-01                                1.358364e+08
# 2021-11-03                                1.388623e+08
# 2021-11-04                                1.372395e+08
#
# DENOM_SOCIAL  051 CRÉDITO 180 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO PRIVADO  \
# DT_COMPTC
# 2021-11-01                                         1.996240e+08
# 2021-11-03                                         1.997775e+08
# 2021-11-04                                         1.998381e+08
#
# DENOM_SOCIAL  051 CRÉDITO 90 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO PRIVADO  \
# DT_COMPTC
# 2021-11-01                                         1.157120e+08
# 2021-11-03                                         1.157761e+08
# 2021-11-04                                         1.158303e+08
#
# DENOM_SOCIAL  051 HF FUNDO DE INVESTIMENTO EM COTAS DE FUNDOS DE INVESTIMENT
# 2021-11-03                                 1.999064e+08
# 2021-11-04                                 1.999344e+08
#
# DENOM_SOCIAL  ÊXITO - FUNDO DE INVESTIMENTO  RENDA FIXA  \
# DT_COMPTC
# 2021-11-01                                 2.233090e+09
# 2021-11-03                                 2.277447e+09
# 2021-11-04                                 2.266904e+09
#
# DENOM_SOCIAL  ÍCARO FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO PRIVADO INVESTIMENTO EXTERIOR  \
# DT_COMPTC
# 2021-11-01                                         1.426568e+08
# 2021-11-03                                         1.432374e+08
# 2021-11-04                                         1.430180e+08
#
# DENOM_SOCIAL  ÓRAMA DI - FUNDO DE INVESTIMENTO RENDA FIXA SIMPLES LONGO PRAZO  \
# DT_COMPTC
# 2021-11-01                                         2.210222e+08
# 2021-11-03                                         2.225892e+08
# 2021-11-04                                         2.213697e+08
#
# DENOM_SOCIAL  ÖLBERG FUNDO DE INVESTIMENTO MULTIMERCADO INVESTIMENTO NO EXTERIOR  \
# DT_COMPTC
# 2021-11-01                                          57090034.70
# 2021-11-03                                          57775332.03
# 2021-11-04                                          57220797.23
#
# DENOM_SOCIAL  ÚNICO - FIC DE FI MULTIMERCADO - CRÉD PRIV - IE - IP
# DT_COMPTC
# 2021-11-01                                         1.014998e+08
# 2021-11-03                                         1.016768e+08
# 2021-11-04                                         1.016382e+08
#
# [3 rows x 6133 columns]

# %%
# data.index = pd.to_datetime(data.index)

# %%
data = data.loc[:, ~data.iloc[0, :].isnull()]

# %%
data = data.loc[:, ~data.iloc[-1, :].isnull()]

# %%
plt.figure(figsize=(10, 6))

for column in np.random.choice(data.columns, size=5, replace=False):
    sns.lineplot(data=data, x=data.index, y=data[column]/1000000000, label = column)

plt.xlabel('Data')
plt.ylabel('Bilhão de Reais')
plt.xticks(rotation=90)

plt.legend(title='Legenda', loc='upper center', bbox_to_anchor=(0.5, -0.3), fancybox=True, shadow=True, ncol=1)

# Ajustando o layout para evitar sobreposições
plt.tight_layout()


# plt.legend()
plt.show()

# %%
CoefficientOfVariation = pd.DataFrame(columns=['beta_mean', 'beta_std', 'Coefficient_of_variation'])

# %%
predictions = dict()
coef = dict()
indexes = dict()

# %%
for column, serie in data.items():
    beta = serie / serie.shift(1) - 1    
    new_data = pd.DataFrame({'beta_mean': [beta.mean()], 'beta_std': [beta.std()], 'Coefficient_of_variation': [beta.mean() / beta.std()]}, 
                        index=[column]) 

    CoefficientOfVariation = pd.concat([CoefficientOfVariation, new_data])
    
    X = []
    y = []

    for index, b in enumerate(beta):
        if(not (np.isnan(b) or np.isinf(b))):
            X.append(index)
            y.append(b)

    X = np.array(X).reshape(-1, 1)
    y = np.array(y).reshape(-1, 1)

    model = LinearRegression()
    model.fit(X, y)

    predictions[column] = model.predict(np.array([i for i in range(735)]).reshape(-1, 1))
    coef[column] = model.coef_

# %%
CoefficientOfVariation = CoefficientOfVariation.loc[~CoefficientOfVariation['Coefficient_of_variation'].isna(), :]

# %%
CoefficientOfVariation.sample(3)
# Out:
#                                                     beta_mean  beta_std  \
# WESTERN ASSET RENDA FIXA ATIVO FUNDO DE INVESTI...  -0.002146  0.001423
# FUNDO DE INVESTIMENTO RENDA FIXA PREVISÃO II         0.000428  0.001472
# BRADESCO PRIVATE FIC DE FUNDOS DE INVESTIMENTO ...   0.001682  0.010050
#
#                                                     Coefficient_of_variation
# WESTERN ASSET RENDA FIXA ATIVO FUNDO DE INVESTI...                 -1.508174
# FUNDO DE INVESTIMENTO RENDA FIXA PREVISÃO II                        0.290912
# BRADESCO PRIVATE FIC DE FUNDOS DE INVESTIMENTO ...                  0.167384

# %%
cdi_daily = 0.00050788

# %%
filter = (CoefficientOfVariation['Coefficient_of_variation'] >= 0.4) & \
         (CoefficientOfVariation['Coefficient_of_variation'] <= 2) & \
         (CoefficientOfVariation['beta_mean'] >= cdi_daily)

# %%
noBest = CoefficientOfVariation[~filter].sort_values(by='beta_mean', ascending=False)

# %%
best = CoefficientOfVariation[filter].sort_values(by='beta_mean', ascending=False)

# %%
plt.figure(figsize=(10, 6))

ax = sns.scatterplot(data=best, x="beta_std", y="beta_mean", marker='+')
ax = sns.scatterplot(data=noBest, x="beta_std", y="beta_mean", marker='+')

ax.set_ylim(0, 0.0175)
ax.set_xlim(0, 0.06)

ax.axhline(y=cdi_daily, linestyle='--', linewidth=2, color='r')
ax.text(x=0.05, y=0.0009, s='CDI', color='r', va='center', ha='right')

ax.text(x=0.006, y=0.009, s='2', color='gray', va='center', ha='right')
ax.text(x=0.027, y=0.009, s='0.4', color='gray', va='center', ha='right')
ax.text(x=0.02, y=0.012, s='Melhores FI', color='g', va='center', ha='right')

plt.plot([0, 0.00875], [0, 0.0175], linestyle='--', linewidth=1, color='gray')
plt.plot([0, 0.04375], [0, 0.0175], linestyle='--', linewidth=1, color='gray')

plt.xlabel('Risco (Desvio padrão do retorno diário/Beta)')
plt.ylabel('Retorno (Média do retorno diário/Beta)')


plt.title('Coeficiente de Variação (Retorno/Risco)')
plt.tight_layout()

plt.show()

# %%
best.head(10)
# Out:
#                                                     beta_mean  beta_std  \
# BRADESCO MULTIGESTORES CRÉDITO PRIVADO PREV PGB...   0.138165  0.132523
# WE CRÉDITO I FUNDO DE INVESTIMENTO MULTIMERCADO...   0.057450  0.065383
# CLAVE ALPHA MACRO FUNDO DE INVESTIMENTO EM COTA...   0.047741  0.090875
# ENCONTRO DAS ÁGUAS FUNDO DE INVESTIMENTO MULTIM...   0.047442  0.114933
# SULAMERICA PREV CONSERVADOR FDO DE INVEST EM CO...   0.041759  0.060256
# NETUNO RENDA FIXA REFERENCIADO DI FUNDO DE INVE...   0.041258  0.090983
# SANTANDER PREV RENDA FIXA CRÉDITO PRIVADO CRESC...   0.038705  0.049896
# BB SABESP FUNDO DE INVESTIMENTO RENDA FIXA           0.035774  0.053129
# BRADESCO FUNDO DE INVESTIMENTO RENDA FIXA REFER...   0.032227  0.053503
# FDO DE INV EM COTAS DE FDOS DE INV CAIXA RENDA ...   0.028790  0.036061
#
#                                                     Coefficient_of_variation
# BRADESCO MULTIGESTORES CRÉDITO PRIVADO PREV PGB...                  1.042571
# WE CRÉDITO I FUNDO DE INVESTIMENTO MULTIMERCADO...                  0.878676
# CLAVE ALPHA MACRO FUNDO DE INVESTIMENTO EM COTA...                  0.525343
# ENCONTRO DAS ÁGUAS FUNDO DE INVESTIMENTO MULTIM...                  0.412782
# SULAMERICA PREV CONSERVADOR FDO DE INVEST EM CO...                  0.693030
# NETUNO RENDA FIXA REFERENCIADO DI FUNDO DE INVE...                  0.453470
# SANTANDER PREV RENDA FIXA CRÉDITO PRIVADO CRESC...                  0.775722
# BB SABESP FUNDO DE INVESTIMENTO RENDA FIXA                          0.673353
# BRADESCO FUNDO DE INVESTIMENTO RENDA FIXA REFER...                  0.602355
# FDO DE INV EM COTAS DE FDOS DE INV CAIXA RENDA ...                  0.798376

# %%
example = 'WE CRÉDITO I FUNDO DE INVESTIMENTO MULTIMERCADO INVESTIMENTO NO EXTERIOR CRÉDITO PRIVADO'

# %%
serie = data[example]

# %%
beta = serie / serie.shift(1) - 1

# %%
sns.lineplot(beta);

# %%
sns.histplot(beta, kde=True, bins=10)
# Out:
# <Axes: xlabel='WE CRÉDITO I FUNDO DE INVESTIMENTO MULTIMERCADO INVESTIMENTO NO EXTERIOR CRÉDITO PRIVADO', ylabel='Count'>

# %%
sns.displot(beta, kde=True, bins=10)

# %%
plt.figure(figsize=(10, 10))

for index, row in best.head(1).iterrows():
    datas_str = data.index.copy()
    datas_lista = datas_str.to_list()
    ultima_data = datas_lista[-1]

    novas_datas = [ultima_data + timedelta(days=i) for i in range(1, 246)]

    datas_lista.extend(novas_datas)
    novo_index = pd.Index(datas_lista)
    
    sns.lineplot(data=data, x=data.index, y=index, label = index)
#     sns.lineplot(x=novo_index, y=predictions[index].reshape(-1), label = index)
    

plt.xlabel('Data')
plt.ylabel('Centena de Milhão de Reais')
plt.xticks(rotation=90)

plt.legend(title='Legenda', loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=True, ncol=1)


# plt.legend()
plt.show()

x = np.array([i for i in range(735)])
y = predictions[index].reshape(-1)


sns.lineplot(x=x, y=y, label = index)
plt.show()

# %%
x = np.array([i for i in range(735)])
y = predictions[index].reshape(-1)


sns.lineplot(x=x, y=y, label = index)
plt.show()

# %%
index = 'WESTERN ASSET PREV FIX FUNDO DE INVESTIMENTO RENDA FIXA CREDITO PRIVADO'

# %%
datas_str = data.index.copy()
datas_lista = datas_str.to_list()
ultima_data = datas_lista[-1]

novas_datas = [ultima_data + timedelta(days=i) for i in range(1, 246)]

datas_lista.extend(novas_datas)
novo_index = pd.Index(datas_lista)

sns.lineplot(x=novo_index, y=predictions[index].reshape(-1), label = index)

# %%
predictions[index].reshape(-1)

# %%
predictions[index]

# %%
cad['VL_PATRIM_LIQ'].

# %%
# MSSQL Server
conn.close()
